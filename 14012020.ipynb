# %%
# Importing all relevant libraries
import pandas as pd
import numpy as np
import shutil
from shutil import *
import csv
import copy
import datetime as dt
from datetime import datetime

# %%
# Copies the file from .txt to .csv
shutil.copyfile("C:\\Cogencis WorkStation\\TMP\\Specific\\Common\\QUOTELISTS2.TXT","C:\\Users\\g.bhargavi\\Desktop\\owtest12.csv")
# Out:
# 'C:\\Users\\g.bhargavi\\Desktop\\owtest12.csv'

# %%
# Code starts: Writing and replacing separators
list_browser = open("C:\\Users\\g.bhargavi\\Desktop\\owtest12.csv","r+")
list_browser = list_browser.read()
list_browser1 = list_browser.replace("|",",")
f= open("C:\\Users\\g.bhargavi\\Desktop\\owtest12.txt","w+")
f.write(list_browser1)
shutil.copyfile("C:\\Users\\g.bhargavi\\Desktop\\owtest12.txt","C:\\Users\\g.bhargavi\\Desktop\\owtest12.csv")

list_browser2 = list_browser1.replace("@",",")
f= open("C:\\Users\\g.bhargavi\\Desktop\\owtest13.txt","w+")
f.write(list_browser2)
shutil.copyfile("C:\\Users\\g.bhargavi\\Desktop\\owtest13.txt","C:\\Users\\g.bhargavi\\Desktop\\owtest13.csv")

f= open("C:\\Users\\g.bhargavi\\Desktop\\owtest14.txt","w+") 
f.write(list_browser2)

df = pd.read_csv("C:\\Users\\g.bhargavi\\Desktop\\owtest13.csv",error_bad_lines=False,engine='python',header=None)
#df.describe()
try: 
    df
except error_bad_lines: 
    print("Error") 
finally: 
    df.head()

L = pd.DataFrame(df)
L.rename(columns={0:'Col1',1:'Extensions',2:'LineID'}, inplace=True)
L.head()
#col_list = ['Col1','Col2','Col3','Col4','Col5','Col6','Col7','Request','Extensions','LineID','Flag','ListOrder','LastUpdate']


#for col in L.columns:
    #print(col)
# Out:
# 882980
# 'C:\\Users\\g.bhargavi\\Desktop\\owtest12.csv'
# 882980
# 'C:\\Users\\g.bhargavi\\Desktop\\owtest13.csv'
# 882980
# Skipping line 274: Expected 3 fields in line 274, saw 4
# Skipping line 275: Expected 3 fields in line 275, saw 4
# Skipping line 279: Expected 3 fields in line 279, saw 4
# Skipping line 281: Expected 3 fields in line 281, saw 4
# Skipping line 317: Expected 3 fields in line 317, saw 4
# Skipping line 337: Expected 3 fields in line 337, saw 4
# Skipping line 380: Expected 3 fields in line 380, saw 4
# Skipping line 446: Expected 3 fields in line 446, saw 4
# Skipping line 569: Expected 3 fields in line 569, saw 5
# Skipping line 570: Expected 3 fields in line 570, saw 5
# Skipping line 571: Expected 3 fields in line 571, saw 5
# Skipping line 572: Expected 3 fields in line 572, saw 5
# Skipping line 573: Expected 3 fields in line 573, saw 5
# Skipping line 574: Expected 3 fields in line 574, saw 5
# Skipping line 634: Expected 3 fields in line 634, saw 4
# Skipping line 678: Expected 3 fields in line 678, saw 5
# Skipping line 782: Expected 3 fields in line 782, saw 4
# Skipping line 798: Expected 3 fields in line 798, saw 4
# Skipping line 1143: Expected 3 fields in line 1143, saw 4
# Skipping line 1150: Expected 3 fields in line 1150, saw 4
# Skipping line 2377: Expected 3 fields in line 2377, saw 4
# Skipping line 5053: Expected 3 fields in line 5053, saw 5
# Skipping line 5128: Expected 3 fields in line 5128, saw 5
# Skipping line 6965: Expected 3 fields in line 6965, saw 4
# Skipping line 6966: Expected 3 fields in line 6966, saw 4
# Skipping line 7795: Expected 3 fields in line 7795, saw 4
# Skipping line 8940: Expected 3 fields in line 8940, saw 4
# Skipping line 8969: Expected 3 fields in line 8969, saw 5
# Skipping line 8970: Expected 3 fields in line 8970, saw 4
#                                                       0           1       2
# 0          Indices;Abu Dhabi;Abu Dhabi Indices ;*.ADS/I         ADS  7169.0
# 1        Indices;Argentina;Main Argentina Indices;*.SBI         SBI    49.0
# 2     Indices;Australia;Main Australia Indices;#IAUS...          AX    50.0
# 3         Indices;Austria;Main Austria Indices;#IVIENNA         VIE    51.0
# 4     Indices;Belgium;Euronext Bruxelles - Main Indi...     BRU+EMI    52.0
# 5            Indices;Brazil;Main Brazil Indices;*.BOI/I         BOI    53.0
# 6     Indices;Canada;TSX Toronto;S&P/TSX Offical Ind...          TO    54.0
# 7     Indices;Canada;TSX Toronto;S&P/TSX Offical Sec...          TO    55.0
# 8     Indices;Canada;TSX Toronto;S&P/TSX Offical Tru...          TO    56.0
# 9     Indices;Canada;TSX Venture;S&P/TSX Venture Com...        TO+V  3363.0
# 10    Indices;Chile;Santiago Indices - Price Return;...         SAN  7165.0
# 11    Indices;Chile;Santiago Indices - Total Return;...         SAN    57.0
# 12        Indices;China;China Indices - CSI;#ICHINA_CSI         CSI    59.0
# 13     Indices;China;China Indices - Shanghai;0000*.CSI         CSI    60.0
# 14      Indices;China;China Indices - Shenzhen;399*.CSI         CSI    61.0
# 15    Indices;China;FTSE Xinhua A 600 Sectorial Indi...         FTS    64.0
# 16    Indices;China;FTSE Xinhua QDII Indices;#FTS_I_...         FTS    63.0
# 17    Indices;China;Main FTSE Xinhua Indices;#FTS_I_...         FTS    62.0
# 18      Indices;China;Main Hong Kong Indices;#IHONGKONG         HKI    58.0
# 19    Indices;Commodity Indices;Major Commodity Indi...  XX+EMI+XDJ     8.0
# 20    Indices;Commodity Indices;Nasdaq Commodity Ind...          XO  7312.0
# 21    Indices;Czech Republic;Main Czech Republic Ind...         PRI    66.0
# 22    Indices;Denmark;FTSE Denmark 20 Index;#IFTSE_D...         FTS    68.0
# 23    Indices;Denmark;Main Denmark Indices;#ICOPENHAGEN     OMX+OMI    67.0
# 24             Indices;Egypt;Main Egypt Indices;*.EGX/I         EGX  7206.0
# 25    Indices;Estonia;Main Estonia Indices;#IOMXTALLINN         TAL    69.0
# 26    Indices;Finland;FTSE Finland 25 Index;#IFTSE_F...         FTS    71.0
# 27      Indices;Finland;Main Finland Indices;#IHELSINKI     OMX+OMI    70.0
# 28    Indices;France;Euronext Paris - Main Indices;#...      PA+EMI    72.0
# 29     Indices;Germany;Main Germany Indices;#IFRANKFURT         XEI    73.0
# ...                                                 ...         ...     ...
# 9032  Strategies;SGX;Calendar Spread;Index;SGX Nikke...          SX  7681.0
# 9033  Strategies;SGX;Calendar Spread;Index;SGX Nikke...          SX  7682.0
# 9034  Strategies;SGX;Calendar Spread;Index;SGX Nikke...          SX  5246.0
# 9035  Strategies;SGX;Calendar Spread;Index;SGX Nikke...          SX  7683.0
# 9036  Strategies;SGX;Calendar Spread;Index;SGX Strai...          SX  7684.0
# 9037  Strategies;SGX;Calendar Spread;Rate;SGX Euroye...          SX  5226.0
# 9038  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7555.0
# 9039  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7556.0
# 9040  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7558.0
# 9041  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7557.0
# 9042  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7559.0
# 9043  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7560.0
# 9044  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7562.0
# 9045  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7563.0
# 9046  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7561.0
# 9047  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7564.0
# 9048  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7566.0
# 9049  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7565.0
# 9050  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7569.0
# 9051  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7568.0
# 9052  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7570.0
# 9053  Strategies;Tokyo Commodity Exchange;Calendar S...         TKT  7567.0
# 9054  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7571.0
# 9055  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7572.0
# 9056  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7573.0
# 9057  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7574.0
# 9058  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7575.0
# 9059  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7576.0
# 9060  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7577.0
# 9061  Strategies;Tokyo Commodity Exchange;Inter-Comm...         TKT  7578.0
#
# [9062 rows x 3 columns]
#                                                    0        1       2
# 0       Indices;Abu Dhabi;Abu Dhabi Indices ;*.ADS/I      ADS  7169.0
# 1     Indices;Argentina;Main Argentina Indices;*.SBI      SBI    49.0
# 2  Indices;Australia;Main Australia Indices;#IAUS...       AX    50.0
# 3      Indices;Austria;Main Austria Indices;#IVIENNA      VIE    51.0
# 4  Indices;Belgium;Euronext Bruxelles - Main Indi...  BRU+EMI    52.0
#                                                 Col1 Extensions  LineID
# 0       Indices;Abu Dhabi;Abu Dhabi Indices ;*.ADS/I        ADS  7169.0
# 1     Indices;Argentina;Main Argentina Indices;*.SBI        SBI    49.0
# 2  Indices;Australia;Main Australia Indices;#IAUS...         AX    50.0
# 3      Indices;Austria;Main Austria Indices;#IVIENNA        VIE    51.0
# 4  Indices;Belgium;Euronext Bruxelles - Main Indi...    BRU+EMI    52.0

# %%
L['Col2'] = ""
L['Col3'] = ""
L['Col4'] = ""
L['Col5'] = ""
L['Col6'] = ""
L['Col7'] = ""
L['Request'] = ""
now = datetime.now()
dt_str = now.strftime('%d/%m/%Y %H:%M:%S')
L['LastUpdate'] = (dt_str)

L.reindex(columns=pd.Index(['Col1','Col2','Col3','Col4','Col5','Col6','Col7','Request','Extensions','LineID','LastUpdate']))

L.head()
# Out:
#                                                    Col1 Col2 Col3 Col4 Col5  \
# 0          Indices;Abu Dhabi;Abu Dhabi Indices ;*.ADS/I
# 1        Indices;Argentina;Main Argentina Indices;*.SBI
# 2     Indices;Australia;Main Australia Indices;#IAUS...
# 3         Indices;Austria;Main Austria Indices;#IVIENNA
# 4     Indices;Belgium;Euronext Bruxelles - Main Indi...
# 5            Indices;Brazil;Main Brazil Indices;*.BOI/I
# 6     Indices;Canada;TSX Toronto;S&P/TSX Offical Ind...
# 7     Indices;Canada;TSX Toronto;S&P/TSX Offical Sec...
# 8     Indices;Canada;TSX Toronto;S&P/TSX Offical Tru...
# 9     Indices;Canada;TSX Venture;S&P/TSX Venture Com...
# 10    Indices;Chile;Santiago Indices - Price Return;...
# 11    Indices;Chile;Santiago Indices - Total Return;...
# 12        Indices;China;China Indices - CSI;#ICHINA_CSI
# 13     Indices;China;China Indices - Shanghai;0000*.CSI
# 14      Indices;China;China Indices - Shenzhen;399*.CSI
# 15    Indices;China;FTSE Xinhua A 600 Sectorial Indi...
# 16    Indices;China;FTSE Xinhua QDII Indices;#FTS_I_...
# 17    Indices;China;Main FTSE Xinhua Indices;#FTS_I_...
# 18      Indices;China;Main Hong Kong Indices;#IHONGKONG
# 19    Indices;Commodity Indices;Major Commodity Indi...
# 20    Indices;Commodity Indices;Nasdaq Commodity Ind...
# 21    Indices;Czech Republic;Main Czech Republic Ind...
# 22    Indices;Denmark;FTSE Denmark 20 Index;#IFTSE_D...
# 23    Indices;Denmark;Main Denmark Indices;#ICOPENHAGEN
# 24             Indices;Egypt;Main Egypt Indices;*.EGX/I
# 25    Indices;Estonia;Main Estonia Indices;#IOMXTALLINN
# 26    Indices;Finland;FTSE Finland 25 Index;#IFTSE_F...
# 27      Indices;Finland;Main Finland Indices;#IHELSINKI
# 28    Indices;France;Euronext Paris - Main Indices;#...
# 29     Indices;Germany;Main Germany Indices;#IFRANKFURT
# ...                                                 ...  ...  ...  ...  ...
# 9032  Strategies;SGX;Calendar Spread;Index;SGX Nikke...
# 9033  Strategies;SGX;Calendar Spread;Index;SGX Nikke...
# 9034  Strategies;SGX;Calendar Spread;Index;SGX Nikke...
# 9035  Strategies;SGX;Calendar Spread;Index;SGX Nikke...
# 9036  Strategies;SGX;Calendar Spread;Index;SGX Strai...
# 9037  Strategies;SGX;Calendar Spread;Rate;SGX Euroye...
# 9038  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9039  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9040  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9041  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9042  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9043  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9044  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9045  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9046  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9047  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9048  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9049  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9050  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9051  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9052  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9053  Strategies;Tokyo Commodity Exchange;Calendar S...
# 9054  Strategies;Tokyo Commodity Exchange;Inter-Comm...
# 9055  Strategies;Tokyo Commodity Exchange;Inter-Comm...
# 9056  Strategies;Tokyo Commodity Exchange;Inter-Comm...
# 9057  Strategies;Tokyo Commodity Exchange;Inter-Comm...
# 9058  Strategies;Tokyo Commodity Exchange;Inter-Comm...
# 9059  Strategies;Tokyo Commodity Exchange;Inter-Comm...
# 9060  Strategies;Tokyo Commodity Exchange;Inter-Comm...
# 9061  Strategies;Tokyo Commodity Exchange;Inter-Comm...
#
#      Col6 Col7 Request  Extensions  LineID           LastUpdate
# 0                              ADS  7169.0  15/01/2020 16:18:55
# 1                              SBI    49.0  15/01/2020 16:18:55
# 2                               AX    50.0  15/01/2020 16:18:55
# 3                              VIE    51.0  15/01/2020 16:18:55
# 4                          BRU+EMI    52.0  15/01/2020 16:18:55
# 5                              BOI    53.0  15/01/2020 16:18:55
# 6                               TO    54.0  15/01/2020 16:18:55
# 7                               TO    55.0  15/01/2020 16:18:55
# 8                               TO    56.0  15/01/2020 16:18:55
# 9                             TO+V  3363.0  15/01/2020 16:18:55
# 10                             SAN  7165.0  15/01/2020 16:18:55
# 11                             SAN    57.0  15/01/2020 16:18:55
# 12                             CSI    59.0  15/01/2020 16:18:55
# 13                             CSI    60.0  15/01/2020 16:18:55
# 14                             CSI    61.0  15/01/2020 16:18:55
# 15                             FTS    64.0  15/01/2020 16:18:55
# 16                             FTS    63.0  15/01/2020 16:18:55
# 17                             FTS    62.0  15/01/2020 16:18:55
# 18                             HKI    58.0  15/01/2020 16:18:55
# 19                      XX+EMI+XDJ     8.0  15/01/2020 16:18:55
# 20                              XO  7312.0  15/01/2020 16:18:55
# 21                             PRI    66.0  15/01/2020 16:18:55
# 22                             FTS    68.0  15/01/2020 16:18:55
# 23                         OMX+OMI    67.0  15/01/2020 16:18:55
# 24                             EGX  7206.0  15/01/2020 16:18:55
# 25                             TAL    69.0  15/01/2020 16:18:55
# 26                             FTS    71.0  15/01/2020 16:18:55
# 27                         OMX+OMI    70.0  15/01/2020 16:18:55
# 28                          PA+EMI    72.0  15/01/2020 16:18:55
# 29                             XEI    73.0  15/01/2020 16:18:55
# ...   ...  ...     ...         ...     ...                  ...
# 9032                            SX  7681.0  15/01/2020 16:18:55
# 9033                            SX  7682.0  15/01/2020 16:18:55
# 9034                            SX  5246.0  15/01/2020 16:18:55
# 9035                            SX  7683.0  15/01/2020 16:18:55
# 9036                            SX  7684.0  15/01/2020 16:18:55
# 9037                            SX  5226.0  15/01/2020 16:18:55
# 9038                           TKT  7555.0  15/01/2020 16:18:55
# 9039                           TKT  7556.0  15/01/2020 16:18:55
# 9040                           TKT  7558.0  15/01/2020 16:18:55
# 9041                           TKT  7557.0  15/01/2020 16:18:55
# 9042                           TKT  7559.0  15/01/2020 16:18:55
# 9043                           TKT  7560.0  15/01/2020 16:18:55
# 9044                           TKT  7562.0  15/01/2020 16:18:55
# 9045                           TKT  7563.0  15/01/2020 16:18:55
# 9046                           TKT  7561.0  15/01/2020 16:18:55
# 9047                           TKT  7564.0  15/01/2020 16:18:55
# 9048                           TKT  7566.0  15/01/2020 16:18:55
# 9049                           TKT  7565.0  15/01/2020 16:18:55
# 9050                           TKT  7569.0  15/01/2020 16:18:55
# 9051                           TKT  7568.0  15/01/2020 16:18:55
# 9052                           TKT  7570.0  15/01/2020 16:18:55
# 9053                           TKT  7567.0  15/01/2020 16:18:55
# 9054                           TKT  7571.0  15/01/2020 16:18:55
# 9055                           TKT  7572.0  15/01/2020 16:18:55
# 9056                           TKT  7573.0  15/01/2020 16:18:55
# 9057                           TKT  7574.0  15/01/2020 16:18:55
# 9058                           TKT  7575.0  15/01/2020 16:18:55
# 9059                           TKT  7576.0  15/01/2020 16:18:55
# 9060                           TKT  7577.0  15/01/2020 16:18:55
# 9061                           TKT  7578.0  15/01/2020 16:18:55
#
# [9062 rows x 11 columns]
#                                                 Col1 Extensions  LineID Col2  \
# 0       Indices;Abu Dhabi;Abu Dhabi Indices ;*.ADS/I        ADS  7169.0
# 1     Indices;Argentina;Main Argentina Indices;*.SBI        SBI    49.0
# 2  Indices;Australia;Main Australia Indices;#IAUS...         AX    50.0
# 3      Indices;Austria;Main Austria Indices;#IVIENNA        VIE    51.0
# 4  Indices;Belgium;Euronext Bruxelles - Main Indi...    BRU+EMI    52.0
#
#   Col3 Col4 Col5 Col6 Col7 Request           LastUpdate
# 0                                   15/01/2020 16:18:55
# 1                                   15/01/2020 16:18:55
# 2                                   15/01/2020 16:18:55
# 3                                   15/01/2020 16:18:55
# 4                                   15/01/2020 16:18:55

# %%
#re_index['Request'] = re_index['Col1'].str.split(';', expand=True)
#re_index.head()

M = L['Col1'].str.split(';').str[-1]
M
N = df.insert(1,"Request",M)
print(M)

#ind2 = pd.DataFrame(["M"])
#ind2.insert (1,"Col8", M)
#ind2
# Out:
# 0                       *.ADS/I
# 1                         *.SBI
# 2                   #IAUSTRALIA
# 3                      #IVIENNA
# 4                    #IBRUSSELS
# 5                       *.BOI/I
# 6                     #ITSX_OFF
# 7                      TT*.TO/I
# 8                      RT*.TO/I
# 9                       J*.TO/I
# 10                #ISANTIAGO_PR
# 11                   #ISANTIAGO
# 12                  #ICHINA_CSI
# 13                    0000*.CSI
# 14                     399*.CSI
# 15      #FTS_I_XIN_A600_SECTORS
# 16              #FTS_I_XIN_QDII
# 17              #FTS_I_XIN_MAIN
# 18                   #IHONGKONG
# 19                #ICOMMODITIES
# 20         #INASDAQ COMMODITIES
# 21                     #IPRAGUE
# 22               #IFTSE_DENMARK
# 23                 #ICOPENHAGEN
# 24                      *.EGX/I
# 25                 #IOMXTALLINN
# 26               #IFTSE_FINLAND
# 27                   #IHELSINKI
# 28                      #IPARIS
# 29                  #IFRANKFURT
#                  ...
# 9032            NS???-???.SX/UC
# 9033            NU???-???.SX/UC
# 9034            NK???-???.SX/UC
# 9035            ND???-???.SX/UC
# 9036            ST???-???.SX/UC
# 9037            EY???-???.SX/UC
# 9038         TGAB???-???.TKT/UC
# 9039         TGCN???-???.TKT/UC
# 9040         RSS3???-???.TKT/UC
# 9041         TGSB???-???.TKT/UC
# 9042         CGAS???-???.TKT/UC
# 9043         CKER???-???.TKT/UC
# 9044         CRUD???-???.TKT/UC
# 9045         GSOL???-???.TKT/UC
# 9046         GASO???-???.TKT/UC
# 9047         KERO???-???.TKT/UC
# 9048         M-GD???-???.TKT/UC
# 9049         GOLD???-???.TKT/UC
# 9050         PALL???-???.TKT/UC
# 9051         M-PT???-???.TKT/UC
# 9052         PLAT???-???.TKT/UC
# 9053         SILV???-???.TKT/UC
# 9054    CGAS???-CKER???.TKT/UMF
# 9055    GSOL???-CRUD???.TKT/UMF
# 9056    GASO???-CRUD???.TKT/UMF
# 9057    GASO???-GSOL???.TKT/UMF
# 9058    GASO???-KERO???.TKT/UMF
# 9059    M-GD???-M-PT???.TKT/UMF
# 9060    KERO???-CRUD???.TKT/UMF
# 9061    KERO???-GSOL???.TKT/UMF
# Name: Col1, Length: 9062, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-79c239572c59> in <module>
#       4 M = L['Col1'].str.split(';').str[-1]
#       5 M
# ----> 6 N = df.insert(1,"Request",M)
#       7 print(M)
#       8
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert Request, already exists

# %%
df5 =DataFrame({'a':[1,2,3,4],'b':[2,4,6,8]})

df5['x']=df.a + df.b
df5['y']=df.a - df.b

# %%
ind = pd.DataFrame([[1, '3 inch screw', 0.5, 0.75],
[2, '2 inch nail', 0.10, 0.25],
[3, 'hammer', 3.00, 5.50],
[4, 'screwdriver', 2.50, 3.00]
], columns=['Product ID', 'Description', 'Cost to Manufacture', 'Price'])

ind

sold_in_bulk = pd.DataFrame(["Yes", "Yes", "No", "No"])

ind.insert (3, "Sold in Bulk", sold_in_bulk)

ind
# Out:
#    Product ID   Description  Cost to Manufacture  Price
# 0           1  3 inch screw                  0.5   0.75
# 1           2   2 inch nail                  0.1   0.25
# 2           3        hammer                  3.0   5.50
# 3           4   screwdriver                  2.5   3.00
#    Product ID   Description  Cost to Manufacture Sold in Bulk  Price
# 0           1  3 inch screw                  0.5          Yes   0.75
# 1           2   2 inch nail                  0.1          Yes   0.25
# 2           3        hammer                  3.0           No   5.50
# 3           4   screwdriver                  2.5           No   3.00

# %%
filename = "C:\\Users\\g.bhargavi\\Desktop\\Titanic Predictions 1.csv"

f.to_csv(filename,index=False)

print('Saved file: ' + filename)

# %%
#x = lb.head = ['a','b','c','d','e','f','g','h','i']
#x = [lb]
#y = lb.splitlines()
#b = y.replace('@',",")
#z = pd.DataFrame(b)[0]
